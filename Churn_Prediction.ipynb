# %%
#Importing the packages we need
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Importing our test data
data = pd.read_csv("C:/Users/chibueze.nnaji/Documents/CampusSquare/Kaggle/train.csv")

# %%
#viewing the first 5 rows of the data
data.head()
# Out:
#   state  account_length      area_code international_plan voice_mail_plan  \
# 0    OH             107  area_code_415                 no             yes
# 1    NJ             137  area_code_415                 no              no
# 2    OH              84  area_code_408                yes              no
# 3    OK              75  area_code_415                yes              no
# 4    MA             121  area_code_510                 no             yes
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     26              161.6              123
# 1                      0              243.4              114
# 2                      0              299.4               71
# 3                      0              166.7              113
# 4                     24              218.2               88
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0             27.47              195.5              103             16.62
# ...

# %%
#checking for missing values
data.isna().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %%
#getting insights on the type of data we are dealing with
data.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     4250.000000            4250.000000        4250.000000
# mean       100.236235               7.631765         180.259600
# std         39.698401              13.439882          54.012373
# min          1.000000               0.000000           0.000000
# 25%         73.000000               0.000000         143.325000
# 50%        100.000000               0.000000         180.450000
# 75%        127.000000              16.000000         216.200000
# max        243.000000              52.000000         351.500000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      4250.000000       4250.000000        4250.000000      4250.000000
# mean         99.907294         30.644682         200.173906       100.176471
# std          19.850817          9.182096          50.249518        19.908591
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4250 entries, 0 to 4249
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          4250 non-null   object
#  1   account_length                 4250 non-null   int64
#  2   area_code                      4250 non-null   object
#  3   international_plan             4250 non-null   object
#  4   voice_mail_plan                4250 non-null   object
#  5   number_vmail_messages          4250 non-null   int64
#  6   total_day_minutes              4250 non-null   float64
#  7   total_day_calls                4250 non-null   int64
#  8   total_day_charge               4250 non-null   float64
#  9   total_eve_minutes              4250 non-null   float64
#  10  total_eve_calls                4250 non-null   int64
#  11  total_eve_charge               4250 non-null   float64
# ...

# %%
#Plotting our data to check if our data is normalized
numerical_data = data.select_dtypes(include="number")
features = numerical_data.columns
sns.set_style("darkgrid")
temp = numerical_data[features]
temp.hist(bins=60,figsize=(30,30),color='green');

# %%
temp
# Out:
#       account_length  number_vmail_messages  total_day_minutes  \
# 0                107                     26              161.6
# 1                137                      0              243.4
# 2                 84                      0              299.4
# 3                 75                      0              166.7
# 4                121                     24              218.2
# ...              ...                    ...                ...
# 4245              83                      0              188.3
# 4246              73                      0              177.9
# 4247              75                      0              170.7
# 4248              50                     40              235.7
# 4249              86                     34              129.4
#
#       total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0                 123             27.47              195.5              103
# ...

# %%
numerical_features
# Out:
# Index(['account_length', 'number_vmail_messages', 'total_day_minutes',
#        'total_day_calls', 'total_day_charge', 'total_eve_minutes',
#        'total_eve_calls', 'total_eve_charge', 'total_night_minutes',
#        'total_night_calls', 'total_night_charge', 'total_intl_minutes',
#        'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls'],
#       dtype='object')

# %%
numerical_data
# Out:
#       account_length  number_vmail_messages  total_day_minutes  \
# 0                107                     26              161.6
# 1                137                      0              243.4
# 2                 84                      0              299.4
# 3                 75                      0              166.7
# 4                121                     24              218.2
# ...              ...                    ...                ...
# 4245              83                      0              188.3
# 4246              73                      0              177.9
# 4247              75                      0              170.7
# 4248              50                     40              235.7
# 4249              86                     34              129.4
#
#       total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# 0                 123             27.47              195.5              103
# ...

# %%
#rescaling the data
from sklearn.preprocessing import MinMaxScaler
rescale = numerical_data.values
scaler = MinMaxScaler()
rescaled_data = scaler.fit_transform(rescale)

# %%
rescaled_data =pd.DataFrame(rescaled_data,columns=features)

# %%
rescaled_data.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     4250.000000            4250.000000        4250.000000
# mean         0.410067               0.146765           0.512830
# std          0.164043               0.258459           0.153663
# min          0.000000               0.000000           0.000000
# 25%          0.297521               0.000000           0.407752
# 50%          0.409091               0.000000           0.513371
# 75%          0.520661               0.307692           0.615078
# max          1.000000               1.000000           1.000000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      4250.000000       4250.000000        4250.000000      4250.000000
# mean          0.605499          0.512796           0.557122         0.589273
# std           0.120308          0.153650           0.139854         0.117109
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
#Normalizing the rescaled_data
from sklearn.preprocessing import Normalizer
normalize = rescaled_data.values
norm = Normalizer()
norm_data = norm.fit_transform(normalize)

# %%
norm_data = pd.DataFrame(norm_data,columns=features)

# %%
norm_data.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     4250.000000            4250.000000        4250.000000
# mean         0.210693               0.072997           0.262183
# std          0.082902               0.128311           0.071637
# min          0.000000               0.000000           0.000000
# 25%          0.152914               0.000000           0.215468
# 50%          0.209906               0.000000           0.264027
# 75%          0.266516               0.158144           0.312596
# max          0.518643               0.498227           0.498300
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      4250.000000       4250.000000        4250.000000      4250.000000
# mean          0.312106          0.262166           0.285394         0.303850
# std           0.062282          0.071631           0.064788         0.061041
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
#Plotting the normalized data 
sns.set_style("darkgrid")
temp1 = norm_data[features]
temp1.hist(bins=60,figsize=(30,30),color='green');

# %%
#combining the normalized data to the main data
data[features] = norm_data[features]

# %%
data.describe()
# Out:
#        account_length  number_vmail_messages  total_day_minutes  \
# count     4250.000000            4250.000000        4250.000000
# mean         0.210693               0.072997           0.262183
# std          0.082902               0.128311           0.071637
# min          0.000000               0.000000           0.000000
# 25%          0.152914               0.000000           0.215468
# 50%          0.209906               0.000000           0.264027
# 75%          0.266516               0.158144           0.312596
# max          0.518643               0.498227           0.498300
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count      4250.000000       4250.000000        4250.000000      4250.000000
# mean          0.312106          0.262166           0.285394         0.303850
# std           0.062282          0.071631           0.064788         0.061041
# min           0.000000          0.000000           0.000000         0.000000
# ...

# %%
data.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'international_plan',
#        'voice_mail_plan', 'number_vmail_messages', 'total_day_minutes',
#        'total_day_calls', 'total_day_charge', 'total_eve_minutes',
#        'total_eve_calls', 'total_eve_charge', 'total_night_minutes',
#        'total_night_calls', 'total_night_charge', 'total_intl_minutes',
#        'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'churn'],
#       dtype='object')

# %%
data['churn'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
#Spliting our data into X and y
X = data.drop('churn',axis=1)
y = data['churn']

# %%
X.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'international_plan',
#        'voice_mail_plan', 'number_vmail_messages', 'total_day_minutes',
#        'total_day_calls', 'total_day_charge', 'total_eve_minutes',
#        'total_eve_calls', 'total_eve_charge', 'total_night_minutes',
#        'total_night_calls', 'total_night_charge', 'total_intl_minutes',
#        'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls'],
#       dtype='object')

# %%
y
# Out:
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
#         ..
# 4245    no
# 4246    no
# 4247    no
# 4248    no
# 4249    no
# Name: churn, Length: 4250, dtype: object

# %%
#converting the string to dummy variables
X_dummy = pd.get_dummies(X)

# %%
X_dummy.head()
# Out:
#    account_length  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0        0.205810               0.234934           0.216019         0.350265
# 1        0.284700               0.000000           0.350800         0.350013
# 2        0.190948               0.000000           0.474218         0.239566
# 3        0.164908               0.000000           0.255761         0.369334
# 4        0.214405               0.199561           0.268409         0.230604
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0          0.215985           0.255661         0.284685          0.255704
# 1          0.350787           0.170887         0.327799          0.170857
# 2          0.474197           0.095915         0.288194          0.095889
# 3          0.255749           0.222591         0.387022          0.222674
# 4          0.268358           0.419386         0.274690          0.419357
#
# ...

# %%
#Splitting the data into train and validation
from sklearn.model_selection import train_test_split
X_train,X_validation,y_train,y_validation = train_test_split(X_dummy,y,train_size=0.8,stratify=y)

# %%
#Training our model with LogisticRegression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#Scoring our model
model.score(X_train,y_train)
# Out:
# 0.8697058823529412

# %%
model.score(X_validation,y_validation)
# Out:
# 0.86

# %%
pred = model.predict(X_validation)

# %%
#Training our model with RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
model1 = RandomForestClassifier()
model1.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model1.score(X_validation,y_validation)
# Out:
# 0.9011764705882352

# %%
#Training our model with GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
model2 = GradientBoostingClassifier()
model2.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
model2.score(X_validation,y_validation)
# Out:
# 0.9823529411764705

# %%
X_test = pd.read_csv("C:/Users/chibueze.nnaji/Documents/CampusSquare/Kaggle/test.csv")

# %%
X_test.head()
# Out:
#    id state  account_length      area_code international_plan voice_mail_plan  \
# 0   1    KS             128  area_code_415                 no             yes
# 1   2    AL             118  area_code_510                yes              no
# 2   3    IA              62  area_code_415                 no              no
# 3   4    VT              93  area_code_510                 no              no
# 4   5    NE             174  area_code_415                 no              no
#
#    number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                     25              265.1              110
# 1                      0              223.4               98
# 2                      0              120.7               70
# 3                      0              190.7              114
# 4                      0              124.3               76
#
#    total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# ...

# %%
X_test = X_test.drop("id",axis=1)

# %%
X_test_dummies = pd.get_dummies(X_test)

# %%
pred1 = model2.predict(X_test_dummies)
pred1
# Out:
# array(['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
#        'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes',
# ...
